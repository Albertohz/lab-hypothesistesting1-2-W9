# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents.

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
df = pd.read_csv('/content/Current_Employee_Names__Salaries__and_Position_Titles (1).csv')

# %%
# Your code here:
df.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
# Your code here:
missing_data = df.isna().sum()
missing_data
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        25161
# Annual Salary         8022
# Hourly Rate          25161
# dtype: int64

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
# Your code here:
employee_type_counts = df["Salary or Hourly"].value_counts()
employee_type_counts
# Out:
# Salary    25161
# Hourly     8022
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
# Your code here:
department_counts = df["Department"].value_counts()
department_counts
# Out:
# POLICE                   13414
# FIRE                      4641
# STREETS & SAN             2198
# OEMC                      2102
# WATER MGMNT               1879
# AVIATION                  1629
# TRANSPORTN                1140
# PUBLIC LIBRARY            1015
# GENERAL SERVICES           980
# FAMILY & SUPPORT           615
# FINANCE                    560
# HEALTH                     488
# CITY COUNCIL               411
# LAW                        407
# BUILDINGS                  269
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           171
# COPA                       116
# BOARD OF ELECTION          107
# DoIT                        99
# PROCUREMENT                 92
# INSPECTOR GEN               87
# MAYOR'S OFFICE              85
# CITY CLERK                  84
# ANIMAL CONTRL               81
# HUMAN RESOURCES             79
# CULTURAL AFFAIRS            65
# BUDGET & MGMT               46
# ADMIN HEARNG                39
# DISABILITIES                28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
# Your code here:
from scipy import stats

# Now we define the hourly wage data for hourly workers
hourly_wages = df[df["Salary or Hourly"] == "Hourly"]["Hourly Rate"]

# What is our null hypothesis value? 30dollars per hour
null_hypothesis_value = 30.0

# Perform a two-sided one-sample t-test / syntax seen in stackoverflow. I was a bit stacked here even looking at the revision notebook of hypothesis testing
t_statistic, p_value = stats.ttest_1samp(hourly_wages, null_hypothesis_value)

# %%
# Set the confidence level at 95%
confidence_level = 0.95

# what is the critical value for the two-sided test?
alpha = 1 - confidence_level
alpha_over_2 = alpha / 2
critical_value = stats.t.ppf(1 - alpha_over_2, df=len(hourly_wages) - 1)

# %%
# let's see the results before reaching a veredict
print("t-statistic:", t_statistic)
print("p-value:", p_value)
print("Critical value:", critical_value)
# Out:
# t-statistic: 20.6198057854942
# p-value: 4.3230240486229894e-92
# Critical value: 1.6449673235204956

# %%
# ellaborate the results checking if the null hypothesis is rejected or not

if abs(t_statistic) > critical_value or p_value < alpha:
    print("Null hypothesis is rejected. Hourly wages are significantly different from $30/hr.")
else:
    print("Null hypothesis is not rejected. Hourly wages are not significantly different from $30/hr.")
# Out:
# Null hypothesis is rejected. Hourly wages are significantly different from $30/hr.

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
# Your code here:
# As above, in here we define the salaries data for police force employees
police_salaries = df[(df["Department"] == "POLICE") & (df["Salary or Hourly"] == "Salary")]["Annual Salary"]

# %%
# now we define the null hyphothesis value
null_hypothesis_value = 86000.0

# %%
# we perform a one-sided one-sample t-test, exactly as above. same process
t_statistic, p_value = stats.ttest_1samp(police_salaries, null_hypothesis_value)

# %%
# set the confidence level again at 95%
confidence_level = 0.95

# what is the critical value for the two-sided test?
alpha = 1 - confidence_level
critical_value = stats.t.ppf(1 - alpha, df=len(police_salaries) - 1)

# %%
# let's see the results before reaching a veredict
print("t-statistic:", t_statistic)
print("p-value:", p_value)
print("Critical value:", critical_value)
# Out:
# t-statistic: 20.6198057854942
# p-value: 4.3230240486229894e-92
# Critical value: 1.6449673235204956

# %%
# ellaborate the results checking if the null hypothesis is rejected or not
if t_statistic > critical_value and p_value < alpha:
    print("Null hypothesis is rejected. Salaries in the police force are higher than $86,000/year.")
else:
    print("Null hypothesis is not rejected. Salaries in the police force are not higher than $86,000/year.")
# Out:
# Null hypothesis is rejected. Salaries in the police force are higher than $86,000/year.

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
# Your code here:
cross_tab = pd.crosstab(df["Department"], df["Salary or Hourly"])
department_with_most_hourly = cross_tab["Hourly"].idxmax()
department_with_most_hourly
# Out:
# 'STREETS & SAN'

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
# Your code here # same explanations as above. I will omit then this time
department_with_most_hourly = cross_tab["Hourly"].idxmax() # whih is streets & san
hourly_wages_department = df[(df["Department"] == department_with_most_hourly) & (df["Salary or Hourly"] == "Hourly")]["Hourly Rate"]
null_hypothesis_value = 35.0
t_statistic, p_value = stats.ttest_1samp(hourly_wages_department, null_hypothesis_value)
confidence_level = 0.95
alpha = 1 - confidence_level
critical_value = stats.t.ppf(1 - alpha, df=len(hourly_wages_department) - 1)

# %%
print("t-statistic:", t_statistic)
print("p-value:", p_value)
print("Critical value:", critical_value)
# Out:
# t-statistic: -9.567447887848152
# p-value: 3.3378530564707717e-21
# Critical value: 1.6456728276882662

# %%
if t_statistic < -critical_value and p_value < alpha:
    print("Null hypothesis is rejected. Hourly wage is less than $35/hour in the department with the most hourly workers.")
else:
    print("Null hypothesis is not rejected. Hourly wage is not less than $35/hour in the department with the most hourly workers.")
# Out:
# Null hypothesis is rejected. Hourly wage is less than $35/hour in the department with the most hourly workers.

# %% [markdown]
# # Challenge 3: To practice - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
# Your code here. I am aware I keep repeating the same libraries but I do it to get the habit.
from scipy import stats
import numpy as np

# %%
# Define the hourly wage data for hourly workers
hourly_wages = df[df["Salary or Hourly"] == "Hourly"]["Hourly Rate"]

# Now we calculate the mean and standard error of the sample
mean_hourly_wage = np.mean(hourly_wages)
std_error = stats.sem(hourly_wages)

# %%
# Setting the confidence level at 95%
confidence_level = 0.95

# Calculate the degrees of freedom as stated in the explanation
degrees_of_freedom = len(hourly_wages) - 1

# Getting the confidence interval
confidence_interval = stats.t.interval(confidence_level, df=degrees_of_freedom, loc=mean_hourly_wage, scale=std_error)

# %%
print("95% Confidence Interval for Mean Hourly Wage:")
print("Lower bound:", confidence_interval[0])
print("Upper bound:", confidence_interval[1])
# Out:
# 95% Confidence Interval for Mean Hourly Wage:
# Lower bound: 32.52345834488425
# Upper bound: 33.05365708767623

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
# Your code here. Same as before (same logic)
police_salaries = df[(df["Department"] == "POLICE") & (df["Salary or Hourly"] == "Salary")]["Annual Salary"]

# %%
# in here we calculate the mean and standard error of the sample
mean_salary = np.mean(police_salaries)
std_error = stats.sem(police_salaries)

# %%
# Setting the confidence level at 95%
confidence_level = 0.95

# Calculate the degrees of freedom as stated in the explanation
degrees_of_freedom = len(police_salaries) - 1

# Getting the confidence interval
confidence_interval = stats.t.interval(confidence_level, df=degrees_of_freedom, loc=mean_salary, scale=std_error)

# %%
print("95% Confidence Interval for Mean Annual Salary of Police Department:")
print("Lower bound:", confidence_interval[0])
print("Upper bound:", confidence_interval[1])
# Out:
# 95% Confidence Interval for Mean Annual Salary of Police Department:
# Lower bound: 86177.05631531784
# Upper bound: 86795.77269094894

# %% [markdown]
# # Bonus Challenge - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
# Your code here:
from statsmodels.stats.proportion import proportions_ztest

# Count the number of hourly workers and total workers
num_hourly_workers = len(df[df["Salary or Hourly"] == "Hourly"])
total_workers = len(df)

# ull hypothesis proportion at 25%
null_hypothesis_proportion = 0.25

# %%
# hypothesis test
z_statistic, p_value = proportions_ztest(count=num_hourly_workers, nobs=total_workers, value=null_hypothesis_proportion)

# confidence level at 95%
confidence_level = 0.95

# %%
# rejected or not???
alpha = 1 - confidence_level
if p_value < alpha:
    print("Null hypothesis is rejected. The proportion of hourly workers is significantly different from 25%.")
else:
    print("Null hypothesis is not rejected. The proportion of hourly workers is not significantly different from 25%.")
# Out:
# Null hypothesis is rejected. The proportion of hourly workers is significantly different from 25%.
