# %% [markdown]
# # Challenge 1 - T-test
#
# In statistics, t-test is used to test if two data samples have a significant difference between their means. There are two types of t-test:
#
# * **Student's t-test** (a.k.a. independent or uncorrelated t-test). This type of t-test is to compare the samples of **two independent populations** (e.g. test scores of students in two different classes). `scipy` provides the [`ttest_ind`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_ind.html) method to conduct student's t-test.
#
# * **Paired t-test** (a.k.a. dependent or correlated t-test). This type of t-test is to compare the samples of **the same population** (e.g. scores of different tests of students in the same class). `scipy` provides the [`ttest_re`](https://docs.scipy.org/doc/scipy-0.15.1/reference/generated/scipy.stats.ttest_rel.html) method to conduct paired t-test.
#
# Both types of t-tests return a number which is called the **p-value**. If p-value is below 0.05, we can confidently declare the null-hypothesis is rejected and the difference is significant. If p-value is between 0.05 and 0.1, we may also declare the null-hypothesis is rejected but we are not highly confident. If p-value is above 0.1 we do not reject the null-hypothesis.
#
# Read more about the t-test in [this article](http://b.link/test50) and [this Quora](http://b.link/unpaired97). Make sure you understand when to use which type of t-test.

# %%
# Import libraries
import pandas as pd
from scipy.stats import ttest_ind

# %% [markdown]
# #### Import dataset
#
# In this challenge we will work on the Pokemon dataset. The goal is to test whether different groups of pokemon (e.g. Legendary vs Normal, Generation 1 vs 2, single-type vs dual-type) have different stats (e.g. HP, Attack, Defense, etc.).

# %%
# Your code here:
df = pd.read_csv('/content/Pokemon (1).csv')

# %% [markdown]
# #### First we want to define a function with which we can test the means of a feature set of two samples.
#
# In the next cell you'll see the annotations of the Python function that explains what this function does and its arguments and returned value. This type of annotation is called **docstring** which is a convention used among Python developers. The docstring convention allows developers to write consistent tech documentations for their codes so that others can read. It also allows some websites to automatically parse the docstrings and display user-friendly documentations.
#
# Follow the specifications of the docstring and complete the function.

# %%
def t_test_features(s1, s2, features=['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total']):
    """Test means of a feature set of two samples

    Args:
        s1 (dataframe): sample 1
        s2 (dataframe): sample 2
        features (list): an array of features to test

    Returns:
        dict: a dictionary of t-test scores for each feature where the feature name is the key and the p-value is the value
    """
    results = {}

    # Your code here

    for feature in features: # we will perform a t-tst for the current feature
        statistic, p_value = ttest_ind(s1[feature], s2[feature])
        results[feature] = p_value

    return results

# %% [markdown]
# #### Using the `t_test_features` function, conduct t-test for Lengendary vs non-Legendary pokemons.
#
# *Hint: your output should look like below:*
#
# ```
# {'HP': 1.0026911708035284e-13,
#  'Attack': 2.520372449236646e-16,
#  'Defense': 4.8269984949193316e-11,
#  'Sp. Atk': 1.5514614112239812e-21,
#  'Sp. Def': 2.2949327864052826e-15,
#  'Speed': 1.049016311882451e-18,
#  'Total': 9.357954335957446e-47}
#  ```

# %%
# Your code here
# we create df for both Legendary and non-Legendary Pokémon
legendary_pokemon = df[df['Legendary'] == True]
non_legendary_pokemon = df[df['Legendary'] == False]

# %%
# t-test function
results = t_test_features(legendary_pokemon, non_legendary_pokemon)
results
# Out:
# {'HP': 3.330647684846191e-15,
#  'Attack': 7.827253003205333e-24,
#  'Defense': 1.5842226094427255e-12,
#  'Sp. Atk': 6.314915770427266e-41,
#  'Sp. Def': 1.8439809580409594e-26,
#  'Speed': 2.3540754436898437e-21,
#  'Total': 3.0952457469652825e-52}

# %% [markdown]
# #### From the test results above, what conclusion can you make? Do Legendary and non-Legendary pokemons have significantly different stats on each feature?

# %%
# Your comment here
# All the p-values for the features are very low, much smaller than 0.05, which suggests a strong evidence to reject the null hypothesis. No diffrence between the means of these features for both legendary and non-legendary pokemon

# Being pragmatic: this means that there are significant statistical differences in the attributes between Legendary and non-Legendary Pokémons.

# %% [markdown]
# #### Next, conduct t-test for Generation 1 and Generation 2 pokemons.

# %%
# Your code here
# dataframes
gen1_pokemon = df[df['Generation'] == 1]
gen2_pokemon = df[df['Generation'] == 2]

# t_test function
results = t_test_features(gen1_pokemon, gen2_pokemon)

# %%
results
# Out:
# {'HP': 0.13791881412813622,
#  'Attack': 0.24050968418101457,
#  'Defense': 0.5407630349194362,
#  'Sp. Atk': 0.14119788176331508,
#  'Sp. Def': 0.16781226231606386,
#  'Speed': 0.0028356954812578704,
#  'Total': 0.5599140649014442}

# %% [markdown]
# # What conclusions can you make?

# %%
# Your comment here
# when the p-values are bigger than the significance level (as we can see in all except for speed) it suggests that tehre is no significant difference in the avg of the atributte between generation 1 and 2.
# in speed, the only exception, we can suggest that there is a significant difference in the avg of speed for both generations

# %% [markdown]
# #### Compare pokemons who have single type vs those having two types.
#
# ---

# %%
# Your code here
# as before, we crate the dataframes
single_type_pokemon = df[df['Type 2'].isna()]
dual_type_pokemon = df[~df['Type 2'].isna()]

# %%
# in here the t_test function
results = t_test_features(single_type_pokemon, dual_type_pokemon)
results
# Out:
# {'HP': 0.11060643144431842,
#  'Attack': 0.00015741395666164396,
#  'Defense': 3.250594205757004e-08,
#  'Sp. Atk': 0.0001454917404035147,
#  'Sp. Def': 0.00010893304795534396,
#  'Speed': 0.024051410794037463,
#  'Total': 1.1749035008828752e-07}

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# same logic as before. we see significant differences in the avg of attributes like attack, sp. atk, sp.df between both types of pokemon.

# %% [markdown]
# #### Now, we want to compare whether there are significant differences of `Attack` vs `Defense`  and  `Sp. Atk` vs `Sp. Def` of all pokemons. Please write your code below.
#
# *Hint: are you comparing different populations or the same population?*

# %%
# Your code here
# first the library
from scipy.stats import ttest_rel

# paired t-test for Attack vs. Defense
statistic_attack_defense, p_value_attack_defense = ttest_rel(df['Attack'], df['Defense'])

# paired t-test for Sp. Atk vs. Sp. Def
statistic_sp_atk_sp_def, p_value_sp_atk_sp_def = ttest_rel(df['Sp. Atk'], df['Sp. Def'])

# %%
# results
print("Paired T-Test Results for Attack vs. Defense:")
print(f'Test Statistic: {statistic_attack_defense}')
print(f'P-Value: {p_value_attack_defense}')

print("\nPaired T-Test Results for Sp. Atk vs. Sp. Def:")
print(f'Test Statistic: {statistic_sp_atk_sp_def}')
print(f'P-Value: {p_value_sp_atk_sp_def}')
# Out:
# Paired T-Test Results for Attack vs. Defense:
# Test Statistic: 4.325566393330478
# P-Value: 1.7140303479358558e-05
#
# Paired T-Test Results for Sp. Atk vs. Sp. Def:
# Test Statistic: 0.853986188453353
# P-Value: 0.3933685997548122

# %% [markdown]
# #### What conclusions can you make?

# %%
# Your comment here
# attack vs defense:
#1) The positive test statistic indicates that, ON AVERAGE, attacks tend to be higher than defense in pokemon populationhe p-value is very small.
#2) It suggests a highly significant difference between the average Attack and Defense stats of all Pokémon

# sp. atk vs sp. df:
#1) test statistics is close to 0. this could indicate that these 2 statistics are similar, ON AVERAGE,
# 2) the p-value is bigger than 0.05 --> no significant difference between the avg of those 2 attributes

# %% [markdown]
# # **PLEASE NOTICE CHALLENGE 2 STARTS HERE. AS I HAVE TO USE GOOGLE COLLAB AND ONLY 1 URL IS ADMITTED IN IRON HACK PLATFORM**

# %% [markdown]
# Challenge 2 - ANOVA
# In statistics, Analysis of Variance (ANOVA) is also used to analyze the differences among group means. The difference between t-test and ANOVA is the former is ued to compare two groups whereas the latter is used to compare three or more groups. Read more about the difference between t-test and ANOVA.
#
# From the ANOVA test, you receive two numbers. The first number is called the F-value which indicates whether your null-hypothesis can be rejected. The critical F-value that rejects the null-hypothesis varies according to the number of total subjects and the number of subject groups in your experiment. In this table you can find the critical values of the F distribution. If you are confused by the massive F-distribution table, don't worry. Skip F-value for now and study it at a later time. In this challenge you only need to look at the p-value.
#
# The p-value is another number yielded by ANOVA which already takes the number of total subjects and the number of experiment groups into consideration. Typically if your p-value is less than 0.05, you can declare the null-hypothesis is rejected.
#
# In this challenge, we want to understand whether there are significant differences among various types of pokemons' Total value, i.e. Grass vs Poison vs Fire vs Dragon... There are many types of pokemons which makes it a perfect use case for ANOVA.

# %%
# Import libraries
import pandas as pd

# %% [markdown]
# To achieve our goal, we use three steps:
#
# Extract the unique values of the pokemon types.
#
# Select dataframes for each unique pokemon type.
#
# Conduct ANOVA analysis across the pokemon types.

# %% [markdown]
# First let's obtain the unique values of the pokemon types. These values should be extracted from Type 1 and Type 2 aggregated. Assign the unique values to a variable called unique_types.
# Hint: the correct number of unique types is 19 including NaN. You can disregard NaN in next step.

# %%
# Your code here
# Unique values from Type 1 and Type 2. Let;s not forget to disregard NaN
unique_types = df[['Type 1', 'Type 2']].values.ravel('K')
unique_types = pd.Series(unique_types).dropna().unique()

# Check the number of unique types (including NaN)
len(unique_types)
# Out:
# 18

# %%
# why do I see 18 when I should see 19? let's check
print(unique_types)
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']

# %%
# I actually only see 18 so not sure why it says in the instructions that I should see 19

# %% [markdown]
# Second we will create a list named pokemon_totals to contain the Total values of each unique type of pokemons.
# Why we use a list instead of a dictionary to store the pokemon Total? It's because ANOVA only tells us whether there is a significant difference of the group means but does not tell which group(s) are significantly different. Therefore, we don't need know which Total belongs to which pokemon type.

# %% [markdown]
# Hints:
#
# Loop through unique_types and append the selected type's Total to pokemon_groups.
# Skip the NaN value in unique_types. NaN is a float variable which you can find out by using type(). The valid pokemon type values are all of the str type.
# At the end, the length of your pokemon_totals should be 18.

# %%
pokemon_totals = []

# looping through unique types
for pokemon_type in unique_types:
    if isinstance(pokemon_type, str):  # I want to check if the type is a string (not NaN)
        # Total values for Pokémon of the current type
        total_values = df[(df['Type 1'] == pokemon_type) | (df['Type 2'] == pokemon_type)]['Total']

        # Append to the list
        pokemon_totals.append(total_values)

# Now I do see 18 ;)
len(pokemon_totals)
# Out:
# 18

# %% [markdown]
# Now we run ANOVA test on pokemon_totals.

# %% [markdown]
# Hints:
#
# To conduct ANOVA, you can use scipy.stats.f_oneway(). Here's the reference.
#
# What if f_oneway throws an error because it does not accept pokemon_totals as a list? The trick is to add a * in front of pokemon_totals, e.g. stats.f_oneway(*pokemon_groups). This trick breaks the list and supplies each list item as a parameter for f_oneway.

# %%
# your code here
# new library
from scipy.stats import f_oneway

# ANOVA test
f_statistic, p_value = f_oneway(*pokemon_totals)

# Print the results
print("ANOVA Results:")
print(f'F-Statistic: {f_statistic}')
print(f'P-Value: {p_value}')
# Out:
# ANOVA Results:
# F-Statistic: 6.6175382960055344
# P-Value: 2.6457458815984803e-15

# %% [markdown]
# Interpret the ANOVA test result. Is the difference significant?

# %%
# Your comment here
# we can say that the difference in Total values among the various Pokémon types is very significant

# regarding p-value: it is very small,  way below the significance level. It suggest that there are significant differences in the means of total values
